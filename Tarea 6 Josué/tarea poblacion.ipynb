# %%
print("Josué Chóez")
# Out:
# Josué Chóez

# %%
import poblacionmendeliana as pob

# %%
cons = [pob.build_population(x, 0.40) for x in range(0, 500)]
print(cons)
# Out:
# [[], [('a', 'a')], [('a', 'A'), ('a', 'a')], [('a', 'a'), ('a', 'a'), ('A', 'a')], [('a', 'a'), ('A', 'A'), ('A', 'A'), ('a', 'a')], [('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'A')], [('a', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('A', 'a')], [('a', 'a'), ('A', 'a'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'A')], [('A', 'A'), ('A', 'A'), ('a', 'a'), ('a', 'A'), ('A', 'a'), ('A', 'a'), ('A', 'a'), ('A', 'a')], [('a', 'a'), ('a', 'a'), ('A', 'A'), ('A', 'A'), ('a', 'a'), ('a', 'A'), ('a', 'a'), ('A', 'A'), ('a', 'a')], [('A', 'a'), ('a', 'A'), ('A', 'A'), ('A', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'A')], [('a', 'a'), ('a', 'A'), ('A', 'a'), ('A', 'a'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('A', 'A'), ('A', 'A'), ('a', 'A'), ('a', 'A')], [('A', 'A'), ('a', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'A'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('A', 'a'), ('A', 'a'), ('A', 'a'), ('A', 'A')], [('A', 'a'), ('a', 'a'), ('A', 'A
# ...

# %%
repro = [pob.reproduce_population(x) for x in cons ]
print(repro)
# Out:
# [[], [('a', 'a')], [('a', 'a'), ('a', 'a')], [('a', 'a'), ('A', 'a'), ('a', 'a')], [('a', 'A'), ('a', 'A'), ('a', 'a'), ('A', 'a')], [('A', 'A'), ('A', 'A'), ('A', 'A'), ('a', 'A'), ('a', 'a')], [('a', 'a'), ('a', 'a'), ('A', 'a'), ('a', 'A'), ('a', 'A'), ('a', 'A')], [('A', 'A'), ('A', 'a'), ('a', 'A'), ('A', 'A'), ('A', 'A'), ('A', 'a'), ('a', 'A')], [('a', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('A', 'a'), ('A', 'a'), ('a', 'a'), ('a', 'A')], [('a', 'A'), ('a', 'A'), ('A', 'A'), ('A', 'A'), ('a', 'a'), ('A', 'A'), ('A', 'a'), ('a', 'A'), ('a', 'A')], [('A', 'A'), ('a', 'A'), ('a', 'A'), ('a', 'A'), ('A', 'a'), ('A', 'a'), ('A', 'a'), ('A', 'a'), ('A', 'A'), ('a', 'a')], [('a', 'A'), ('A', 'a'), ('A', 'a'), ('a', 'A'), ('a', 'a'), ('A', 'a'), ('a', 'a'), ('A', 'A'), ('a', 'a'), ('a', 'a'), ('a', 'a')], [('a', 'A'), ('a', 'a'), ('A', 'a'), ('a', 'A'), ('A', 'A'), ('A', 'a'), ('a', 'A'), ('A', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a'), ('a', 'a')], [('A', 'A'), ('a', 'a'), ('A', 'a
# ...

# %%
freq = [pob.compute_frequencies(x) for x in repro]
print(freq)
# Out:
# [{'AA': 0, 'aa': 0, 'Aa': 0, 'aA': 0}, {'AA': 0, 'aa': 1, 'Aa': 0, 'aA': 0}, {'AA': 0, 'aa': 2, 'Aa': 0, 'aA': 0}, {'AA': 0, 'aa': 2, 'Aa': 1, 'aA': 0}, {'AA': 0, 'aa': 1, 'Aa': 1, 'aA': 2}, {'AA': 3, 'aa': 1, 'Aa': 0, 'aA': 1}, {'AA': 0, 'aa': 2, 'Aa': 1, 'aA': 3}, {'AA': 3, 'aa': 0, 'Aa': 2, 'aA': 2}, {'AA': 0, 'aa': 4, 'Aa': 2, 'aA': 2}, {'AA': 3, 'aa': 1, 'Aa': 1, 'aA': 4}, {'AA': 2, 'aa': 1, 'Aa': 4, 'aA': 3}, {'AA': 1, 'aa': 5, 'Aa': 3, 'aA': 2}, {'AA': 1, 'aa': 5, 'Aa': 3, 'aA': 3}, {'AA': 1, 'aa': 6, 'Aa': 5, 'aA': 1}, {'AA': 0, 'aa': 8, 'Aa': 1, 'aA': 5}, {'AA': 0, 'aa': 5, 'Aa': 7, 'aA': 3}, {'AA': 7, 'aa': 3, 'Aa': 3, 'aA': 3}, {'AA': 4, 'aa': 5, 'Aa': 6, 'aA': 2}, {'AA': 2, 'aa': 5, 'Aa': 4, 'aA': 7}, {'AA': 6, 'aa': 3, 'Aa': 5, 'aA': 5}, {'AA': 3, 'aa': 4, 'Aa': 8, 'aA': 5}, {'AA': 3, 'aa': 8, 'Aa': 9, 'aA': 1}, {'AA': 6, 'aa': 5, 'Aa': 8, 'aA': 3}, {'AA': 3, 'aa': 7, 'Aa': 5, 'aA': 8}, {'AA': 2, 'aa': 10, 'Aa': 8, 'aA': 4}, {'AA': 2, 'aa': 11, 'Aa': 6, 'aA': 6}, {'AA': 
# ...
